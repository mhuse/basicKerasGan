# %%
from keras.layers import Input, Reshape, Dropout, Dense, Flatten, BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model, load_model
from keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Run this for Google CoLab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
GENERATE_RES = 2 # (1=32, 2=64, 3=96, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16
SAVE_FREQ = 100

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/My Drive'
EPOCHS = 30000
BATCH_SIZE = 32

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 64px square images.

# %%
ls
# Out:
# 'My Drive'/

# %%
training_binary_path = os.path.join(DATA_PATH,f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH,'new2folder')
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data / 127.5 - 1.

  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/My Drive/training_data_64_64.npy
# Loading previous training pickle...

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    for i in range(GENERATE_RES):
      model.add(UpSampling2D())
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    input = Input(shape=(seed_size,))
    generated_image = model(input)

    return Model(input,generated_image)


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    input_image = Input(shape=image_shape)

    validity = model(input_image)

    return Model(input_image, validity)
  
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)
optimizer = Adam(1.5e-4,0.5) # learning rate and momentum adjusted from paper

discriminator = build_discriminator(image_shape)
discriminator.compile(loss="binary_crossentropy",optimizer=optimizer,metrics=["accuracy"])
generator = build_generator(SEED_SIZE,IMAGE_CHANNELS)

random_input = Input(shape=(SEED_SIZE,))

generated_image = generator(random_input)

discriminator.trainable = False

validity = discriminator(generated_image)

combined = Model(random_input,validity)
combined.compile(loss="binary_crossentropy",optimizer=optimizer,metrics=["accuracy"])

# %%
y_real = np.ones((BATCH_SIZE,1))
y_fake = np.zeros((BATCH_SIZE,1))

fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, SEED_SIZE))

cnt = 1
for epoch in range(EPOCHS):
    idx = np.random.randint(0,training_data.shape[0],BATCH_SIZE)
    x_real = training_data[idx]

    # Generate some images
    seed = np.random.normal(0,1,(BATCH_SIZE,SEED_SIZE))
    x_fake = generator.predict(seed)

    # Train discriminator on real and fake
    discriminator_metric_real = discriminator.train_on_batch(x_real,y_real)
    discriminator_metric_generated = discriminator.train_on_batch(x_fake,y_fake)
    discriminator_metric = 0.5 * np.add(discriminator_metric_real,discriminator_metric_generated)
    
    # Train generator on Calculate losses
    generator_metric = combined.train_on_batch(seed,y_real)
    
    # Time for an update?
    if epoch % SAVE_FREQ == 0:
        save_images(cnt, fixed_seed)
        cnt += 1
        print(f"Epoch {epoch}, Discriminator accuarcy: {discriminator_metric[1]}, Generator accuracy: {generator_metric[1]}")
        
generator.save(os.path.join(DATA_PATH,"face_generator.h5"))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 0, Discriminator accuarcy: 0.296875, Generator accuracy: 0.90625
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 100, Discriminator accuarcy: 0.90625, Generator accuracy: 0.65625
# Epoch 200, Discriminator accuarcy: 0.9375, Generator accuracy: 0.125
# Epoch 300, Discriminator accuarcy: 0.515625, Generator accuracy: 0.53125
# Epoch 400, Discriminator accuarcy: 0.640625, Generator accuracy: 0.0625
# Epoch 500, Discriminator accuarcy: 0.84375, Generator accuracy: 0.03125
# Epoch 600, Discriminator accuarcy: 0.28125, Generator accuracy: 0.09375
# Epoch 700, Discriminator accuarcy: 0.671875, Generator accuracy: 0.0
# Epoch 800, Discriminator accuarcy: 0.765625, Generator accuracy: 0.09375
# Epoch 900, Discriminator accuarcy: 0.28125, Generator accuracy: 0.375
# Epoch 1000, Discriminator accuarcy: 0.671875, Generator accuracy: 0.28125
# Epoch 1100, Discriminator accuarcy: 0.6875, Generator accuracy: 0.28125
# Epoch 1200, Discriminator accuarcy: 0.65625, Generator accuracy: 0.1875
# Epoch 1300, Discriminator accuarcy: 0.625, Generator accuracy: 0.15625
# Epoch 1400, Discriminator accuarcy: 0.609375, Generator accuracy: 0.1875
# Epoch 1500, Discriminator accuarcy: 0.546875, Generator accuracy: 0.03125
# Epoch 1600, Discriminator accuarcy: 0.65625, Generator accuracy: 0.0
# Epoch 1700, Discriminator accuarcy: 0.703125, Generator accuracy: 0.375
# Epoch 1800, Discriminator accuarcy: 0.75, Generator accuracy: 0.1875
# Epoch 1900, Discriminator accuarcy: 0.828125, Generator accuracy: 0.1875
# Epoch 2000, Discriminator accuarcy: 0.78125, Generator accuracy: 0.15625
# Epoch 2100, Discriminator accuarcy: 0.6875, Generator accuracy: 0.03125
# Epoch 2200, Discriminator accuarcy: 0.703125, Generator accuracy: 0.25
# Epoch 2300, Discriminator accuarcy: 0.578125, Generator accuracy: 0.09375
# Epoch 2400, Discriminator accuarcy: 0.796875, Generator accuracy: 0.28125
# Epoch 2500, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 2600, Discriminator accuarcy: 0.8125, Generator accuracy: 0.125
# Epoch 2700, Discriminator accuarcy: 0.75, Generator accuracy: 0.125
# Epoch 2800, Discriminator accuarcy: 0.65625, Generator accuracy: 0.0625
# Epoch 2900, Discriminator accuarcy: 0.734375, Generator accuracy: 0.1875
# Epoch 3000, Discriminator accuarcy: 0.6875, Generator accuracy: 0.09375
# Epoch 3100, Discriminator accuarcy: 0.765625, Generator accuracy: 0.09375
# Epoch 3200, Discriminator accuarcy: 0.6875, Generator accuracy: 0.03125
# Epoch 3300, Discriminator accuarcy: 0.78125, Generator accuracy: 0.21875
# Epoch 3400, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 3500, Discriminator accuarcy: 0.796875, Generator accuracy: 0.28125
# Epoch 3600, Discriminator accuarcy: 0.421875, Generator accuracy: 0.0625
# Epoch 3700, Discriminator accuarcy: 0.75, Generator accuracy: 0.1875
# Epoch 3800, Discriminator accuarcy: 0.75, Generator accuracy: 0.125
# Epoch 3900, Discriminator accuarcy: 0.734375, Generator accuracy: 0.09375
# Epoch 4000, Discriminator accuarcy: 0.65625, Generator accuracy: 0.0
# Epoch 4100, Discriminator accuarcy: 0.53125, Generator accuracy: 0.09375
# Epoch 4200, Discriminator accuarcy: 0.71875, Generator accuracy: 0.03125
# Epoch 4300, Discriminator accuarcy: 0.875, Generator accuracy: 0.40625
# Epoch 4400, Discriminator accuarcy: 0.71875, Generator accuracy: 0.09375
# Epoch 4500, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0
# Epoch 4600, Discriminator accuarcy: 0.640625, Generator accuracy: 0.0625
# Epoch 4700, Discriminator accuarcy: 0.828125, Generator accuracy: 0.09375
# Epoch 4800, Discriminator accuarcy: 0.53125, Generator accuracy: 0.40625
# Epoch 4900, Discriminator accuarcy: 0.625, Generator accuracy: 0.15625
# Epoch 5000, Discriminator accuarcy: 0.765625, Generator accuracy: 0.125
# Epoch 5100, Discriminator accuarcy: 0.640625, Generator accuracy: 0.0
# Epoch 5200, Discriminator accuarcy: 1.0, Generator accuracy: 0.34375
# Epoch 5300, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 5400, Discriminator accuarcy: 0.671875, Generator accuracy: 0.375
# Epoch 5500, Discriminator accuarcy: 0.390625, Generator accuracy: 0.09375
# Epoch 5600, Discriminator accuarcy: 0.6875, Generator accuracy: 0.1875
# Epoch 5700, Discriminator accuarcy: 0.71875, Generator accuracy: 0.0625
# Epoch 5800, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0625
# Epoch 5900, Discriminator accuarcy: 0.875, Generator accuracy: 0.21875
# Epoch 6000, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 6100, Discriminator accuarcy: 0.6875, Generator accuracy: 0.34375
# Epoch 6200, Discriminator accuarcy: 0.734375, Generator accuracy: 0.03125
# Epoch 6300, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 6400, Discriminator accuarcy: 0.71875, Generator accuracy: 0.125
# Epoch 6500, Discriminator accuarcy: 0.734375, Generator accuracy: 0.21875
# Epoch 6600, Discriminator accuarcy: 0.671875, Generator accuracy: 0.0625
# Epoch 6700, Discriminator accuarcy: 0.78125, Generator accuracy: 0.1875
# Epoch 6800, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0625
# Epoch 6900, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 7000, Discriminator accuarcy: 0.921875, Generator accuracy: 0.03125
# Epoch 7100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.125
# Epoch 7200, Discriminator accuarcy: 0.5625, Generator accuracy: 0.21875
# Epoch 7300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.09375
# Epoch 7400, Discriminator accuarcy: 0.828125, Generator accuracy: 0.15625
# Epoch 7500, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0625
# Epoch 7600, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 7700, Discriminator accuarcy: 0.875, Generator accuracy: 0.0625
# Epoch 7800, Discriminator accuarcy: 0.703125, Generator accuracy: 0.21875
# Epoch 7900, Discriminator accuarcy: 0.9375, Generator accuracy: 0.125
# Epoch 8000, Discriminator accuarcy: 0.78125, Generator accuracy: 0.0
# Epoch 8100, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 8200, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 8300, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0625
# Epoch 8400, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 8500, Discriminator accuarcy: 0.859375, Generator accuracy: 0.15625
# Epoch 8600, Discriminator accuarcy: 0.828125, Generator accuracy: 0.25
# Epoch 8700, Discriminator accuarcy: 0.6875, Generator accuracy: 0.09375
# Epoch 8800, Discriminator accuarcy: 0.8125, Generator accuracy: 0.125
# Epoch 8900, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 9000, Discriminator accuarcy: 0.96875, Generator accuracy: 0.09375
# Epoch 9100, Discriminator accuarcy: 0.90625, Generator accuracy: 0.21875
# Epoch 9200, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 9300, Discriminator accuarcy: 0.65625, Generator accuracy: 0.03125
# Epoch 9400, Discriminator accuarcy: 0.828125, Generator accuracy: 0.09375
# Epoch 9500, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 9600, Discriminator accuarcy: 0.9375, Generator accuracy: 0.09375
# Epoch 9700, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 9800, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0625
# Epoch 9900, Discriminator accuarcy: 0.5, Generator accuracy: 0.15625
# Epoch 10000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.21875
# Epoch 10100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 10200, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 10300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 10400, Discriminator accuarcy: 0.984375, Generator accuracy: 0.21875
# Epoch 10500, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 10600, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0
# Epoch 10700, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 10800, Discriminator accuarcy: 0.90625, Generator accuracy: 0.3125
# Epoch 10900, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 11000, Discriminator accuarcy: 0.921875, Generator accuracy: 0.1875
# Epoch 11100, Discriminator accuarcy: 0.9375, Generator accuracy: 0.125
# Epoch 11200, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0
# Epoch 11300, Discriminator accuarcy: 0.796875, Generator accuracy: 0.03125
# Epoch 11400, Discriminator accuarcy: 0.703125, Generator accuracy: 0.0625
# Epoch 11500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 11600, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 11700, Discriminator accuarcy: 0.859375, Generator accuracy: 0.1875
# Epoch 11800, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 11900, Discriminator accuarcy: 0.796875, Generator accuracy: 0.125
# Epoch 12000, Discriminator accuarcy: 0.875, Generator accuracy: 0.0625
# Epoch 12100, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0
# Epoch 12200, Discriminator accuarcy: 0.875, Generator accuracy: 0.1875
# Epoch 12300, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 12400, Discriminator accuarcy: 0.875, Generator accuracy: 0.15625
# Epoch 12500, Discriminator accuarcy: 0.453125, Generator accuracy: 0.1875
# Epoch 12600, Discriminator accuarcy: 0.953125, Generator accuracy: 0.28125
# Epoch 12700, Discriminator accuarcy: 0.875, Generator accuracy: 0.15625
# Epoch 12800, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 12900, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 13000, Discriminator accuarcy: 0.640625, Generator accuracy: 0.3125
# Epoch 13100, Discriminator accuarcy: 0.953125, Generator accuracy: 0.0625
# Epoch 13200, Discriminator accuarcy: 0.8125, Generator accuracy: 0.25
# Epoch 13300, Discriminator accuarcy: 0.828125, Generator accuracy: 0.09375
# Epoch 13400, Discriminator accuarcy: 0.8125, Generator accuracy: 0.1875
# Epoch 13500, Discriminator accuarcy: 0.703125, Generator accuracy: 0.09375
# Epoch 13600, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 13700, Discriminator accuarcy: 0.78125, Generator accuracy: 0.15625
# Epoch 13800, Discriminator accuarcy: 0.65625, Generator accuracy: 0.1875
# Epoch 13900, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 14000, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 14100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 14200, Discriminator accuarcy: 0.75, Generator accuracy: 0.21875
# Epoch 14300, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 14400, Discriminator accuarcy: 0.859375, Generator accuracy: 0.1875
# Epoch 14500, Discriminator accuarcy: 0.875, Generator accuracy: 0.0625
# Epoch 14600, Discriminator accuarcy: 0.8125, Generator accuracy: 0.125
# Epoch 14700, Discriminator accuarcy: 0.8125, Generator accuracy: 0.125
# Epoch 14800, Discriminator accuarcy: 0.78125, Generator accuracy: 0.0
# Epoch 14900, Discriminator accuarcy: 0.6875, Generator accuracy: 0.09375
# Epoch 15000, Discriminator accuarcy: 0.609375, Generator accuracy: 0.09375
# Epoch 15100, Discriminator accuarcy: 0.703125, Generator accuracy: 0.125
# Epoch 15200, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0
# Epoch 15300, Discriminator accuarcy: 0.796875, Generator accuracy: 0.125
# Epoch 15400, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0625
# Epoch 15500, Discriminator accuarcy: 0.71875, Generator accuracy: 0.09375
# Epoch 15600, Discriminator accuarcy: 0.796875, Generator accuracy: 0.15625
# Epoch 15700, Discriminator accuarcy: 0.90625, Generator accuracy: 0.15625
# Epoch 15800, Discriminator accuarcy: 0.828125, Generator accuracy: 0.15625
# Epoch 15900, Discriminator accuarcy: 0.890625, Generator accuracy: 0.15625
# Epoch 16000, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0
# Epoch 16100, Discriminator accuarcy: 0.875, Generator accuracy: 0.0625
# Epoch 16200, Discriminator accuarcy: 0.75, Generator accuracy: 0.09375
# Epoch 16300, Discriminator accuarcy: 0.828125, Generator accuracy: 0.15625
# Epoch 16400, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0
# Epoch 16500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 16600, Discriminator accuarcy: 0.765625, Generator accuracy: 0.1875
# Epoch 16700, Discriminator accuarcy: 0.8125, Generator accuracy: 0.15625
# Epoch 16800, Discriminator accuarcy: 0.75, Generator accuracy: 0.09375
# Epoch 16900, Discriminator accuarcy: 0.90625, Generator accuracy: 0.1875
# Epoch 17000, Discriminator accuarcy: 0.890625, Generator accuracy: 0.1875
# Epoch 17100, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 17200, Discriminator accuarcy: 0.71875, Generator accuracy: 0.1875
# Epoch 17300, Discriminator accuarcy: 0.765625, Generator accuracy: 0.03125
# Epoch 17400, Discriminator accuarcy: 0.734375, Generator accuracy: 0.03125
# Epoch 17500, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 17600, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 17700, Discriminator accuarcy: 0.71875, Generator accuracy: 0.15625
# Epoch 17800, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0625
# Epoch 17900, Discriminator accuarcy: 0.78125, Generator accuracy: 0.0625
# Epoch 18000, Discriminator accuarcy: 0.8125, Generator accuracy: 0.3125
# Epoch 18100, Discriminator accuarcy: 0.6875, Generator accuracy: 0.03125
# Epoch 18200, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 18300, Discriminator accuarcy: 0.8125, Generator accuracy: 0.09375
# Epoch 18400, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 18500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 18600, Discriminator accuarcy: 0.71875, Generator accuracy: 0.125
# Epoch 18700, Discriminator accuarcy: 0.703125, Generator accuracy: 0.15625
# Epoch 18800, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 18900, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 19000, Discriminator accuarcy: 0.75, Generator accuracy: 0.125
# Epoch 19100, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 19200, Discriminator accuarcy: 1.0, Generator accuracy: 0.1875
# Epoch 19300, Discriminator accuarcy: 0.796875, Generator accuracy: 0.125
# Epoch 19400, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 19500, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 19600, Discriminator accuarcy: 0.84375, Generator accuracy: 0.1875
# Epoch 19700, Discriminator accuarcy: 0.859375, Generator accuracy: 0.1875
# Epoch 19800, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 19900, Discriminator accuarcy: 0.765625, Generator accuracy: 0.125
# Epoch 20000, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 20100, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 20200, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 20300, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 20400, Discriminator accuarcy: 0.6875, Generator accuracy: 0.15625
# Epoch 20500, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 20600, Discriminator accuarcy: 0.75, Generator accuracy: 0.09375
# Epoch 20700, Discriminator accuarcy: 0.703125, Generator accuracy: 0.09375
# Epoch 20800, Discriminator accuarcy: 0.796875, Generator accuracy: 0.1875
# Epoch 20900, Discriminator accuarcy: 0.84375, Generator accuracy: 0.15625
# Epoch 21000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 21100, Discriminator accuarcy: 0.921875, Generator accuracy: 0.28125
# Epoch 21200, Discriminator accuarcy: 0.84375, Generator accuracy: 0.125
# Epoch 21300, Discriminator accuarcy: 0.828125, Generator accuracy: 0.09375
# Epoch 21400, Discriminator accuarcy: 0.65625, Generator accuracy: 0.03125
# Epoch 21500, Discriminator accuarcy: 0.828125, Generator accuracy: 0.1875
# Epoch 21600, Discriminator accuarcy: 0.90625, Generator accuracy: 0.09375
# Epoch 21700, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 21800, Discriminator accuarcy: 0.78125, Generator accuracy: 0.15625
# Epoch 21900, Discriminator accuarcy: 0.953125, Generator accuracy: 0.09375
# Epoch 22000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.03125
# Epoch 22100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 22200, Discriminator accuarcy: 0.859375, Generator accuracy: 0.15625
# Epoch 22300, Discriminator accuarcy: 0.78125, Generator accuracy: 0.125
# Epoch 22400, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 22500, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 22600, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0625
# Epoch 22700, Discriminator accuarcy: 0.8125, Generator accuracy: 0.03125
# Epoch 22800, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0625
# Epoch 22900, Discriminator accuarcy: 0.6875, Generator accuracy: 0.21875
# Epoch 23000, Discriminator accuarcy: 0.859375, Generator accuracy: 0.09375
# Epoch 23100, Discriminator accuarcy: 0.921875, Generator accuracy: 0.1875
# Epoch 23200, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 23300, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0625
# Epoch 23400, Discriminator accuarcy: 0.90625, Generator accuracy: 0.09375
# Epoch 23500, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 23600, Discriminator accuarcy: 0.828125, Generator accuracy: 0.1875
# Epoch 23700, Discriminator accuarcy: 0.609375, Generator accuracy: 0.1875
# Epoch 23800, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 23900, Discriminator accuarcy: 0.703125, Generator accuracy: 0.03125
# Epoch 24000, Discriminator accuarcy: 0.734375, Generator accuracy: 0.09375
# Epoch 24100, Discriminator accuarcy: 0.78125, Generator accuracy: 0.15625
# Epoch 24200, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 24300, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 24400, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 24500, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 24600, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 24700, Discriminator accuarcy: 0.75, Generator accuracy: 0.09375
# Epoch 24800, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 24900, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 25000, Discriminator accuarcy: 0.859375, Generator accuracy: 0.1875
# Epoch 25100, Discriminator accuarcy: 0.8125, Generator accuracy: 0.125
# Epoch 25200, Discriminator accuarcy: 0.921875, Generator accuracy: 0.125
# Epoch 25300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 25400, Discriminator accuarcy: 0.5625, Generator accuracy: 0.15625
# Epoch 25500, Discriminator accuarcy: 0.734375, Generator accuracy: 0.09375
# Epoch 25600, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 25700, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 25800, Discriminator accuarcy: 0.75, Generator accuracy: 0.0
# Epoch 25900, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 26000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 26100, Discriminator accuarcy: 0.859375, Generator accuracy: 0.09375
# Epoch 26200, Discriminator accuarcy: 0.828125, Generator accuracy: 0.21875
# Epoch 26300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 26400, Discriminator accuarcy: 0.875, Generator accuracy: 0.0625
# Epoch 26500, Discriminator accuarcy: 0.953125, Generator accuracy: 0.03125
# Epoch 26600, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 26700, Discriminator accuarcy: 0.765625, Generator accuracy: 0.09375
# Epoch 26800, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 26900, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 27000, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0
# Epoch 27100, Discriminator accuarcy: 0.734375, Generator accuracy: 0.28125
# Epoch 27200, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 27300, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 27400, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 27500, Discriminator accuarcy: 0.796875, Generator accuracy: 0.03125
# Epoch 27600, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0
# Epoch 27700, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 27800, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0
# Epoch 27900, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0625
# Epoch 28000, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 28100, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 28200, Discriminator accuarcy: 0.75, Generator accuracy: 0.03125
# Epoch 28300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.15625
# Epoch 28400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 28500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 28600, Discriminator accuarcy: 0.78125, Generator accuracy: 0.1875
# Epoch 28700, Discriminator accuarcy: 0.75, Generator accuracy: 0.1875
# Epoch 28800, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 28900, Discriminator accuarcy: 0.828125, Generator accuracy: 0.15625
# Epoch 29000, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0625
# Epoch 29100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 29200, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 29300, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 29400, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 29500, Discriminator accuarcy: 0.875, Generator accuracy: 0.0625
# Epoch 29600, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 29700, Discriminator accuarcy: 0.828125, Generator accuracy: 0.03125
# Epoch 29800, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 29900, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
